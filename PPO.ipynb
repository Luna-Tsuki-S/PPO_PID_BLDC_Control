# %% [markdown]
# # install

# %%
# !pip install stable-baselines3 gym numpy matplotlib shimmy
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install --upgrade stable-baselines3 gymnasium
# !pip install scipy matplotlib pandas
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 4.3 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, shimmy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 shimmy-2.0.0 stable-baselines3-2.6.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 80.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 51.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.8.87 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 105.1 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-9.1.0.70-py3-none-manylinux2014_x86_64.whl (663.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 1.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.11.3.6 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.3.0.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux1_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 13.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.1.48 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.5.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 6.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.21.5 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.21.5-py3-none-manylinux2014_x86_64.whl (147.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 7.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.8.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nvtx_cu11-11.8.86-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.3 MB/s eta 0:00:00
# Collecting triton==3.3.1 (from torch)
#   Downloading https://download.pytorch.org/whl/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl (905.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 MB 2.3 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 6.9 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 88.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 88.3 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 95.6 MB/s eta 0:00:00
# Installing collected packages: triton, sympy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.6.0+cu124
#     Uninstalling torchaudio-2.6.0+cu124:
#       Successfully uninstalled torchaudio-2.6.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.1+cu118 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-9.1.0.70 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.21.5 nvidia-nvtx-cu11-11.8.86 sympy-1.13.3 torch-2.7.1+cu118 torchaudio-2.7.1+cu118 torchvision-0.22.1+cu118 triton-3.3.1
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.11/dist-packages (2.6.0)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.7.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# # Temp / Humid

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 環境（使用 CSV）
class THBLDC(gym.Env):
    def __init__(self, csv_path):
        self.data = pd.read_csv(csv_path)
        self.max_steps = len(self.data)

        # 狀態空間：2 維連續數值（標準化）
        self.observation_space = spaces.Box(low=0, high=1, shape=(2,), dtype=np.float32)

        # 動作空間：0 to 1650 rpm
        self.action_space = spaces.Discrete(1651)
        self.current_step = 0

    def reset(self):
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        row = self.data.iloc[self.current_step]
        return np.array([
            row['Temperature'] / 100,
            row['Humidity'] / 100
        ], dtype=np.float32)

    def step(self, action):
        row = self.data.iloc[self.current_step]
        done = False
        reward = 0



        temp = row['Temperature']
        humid = row['Humidity']

        # RPM rawl
        kwh = ((1650 * (action / 1650) ** 3) * 0.1) / 1000
        tr_fan = 0.006
        save_rate = (kwh - tr_fan) / tr_fan


        # 節能效果（希望 kWh 越少越好）
        reward -= kwh  # 直接懲罰功耗

        # 溫度舒適度（22–28°C 為舒適範圍）
        reward -= abs(temp - 25) * 0.1  # 越接近 25°C 越好

        # 濕度舒適度（40–60% 為舒適範圍）
        reward -= abs(humid - 50) * 0.05  # 越接近 50% 越好

        # 若功耗比基準省電 30% 以上，額外加分
        if save_rate >= 0.3:
            reward += 0.5

        # 若風速在舒適風速區間（ex. 500~900 RPM），額外加分
        if 500 <= action <= 900:
            reward += 0.2

        # 安全風速 <= 1300 RPM
        if action <= 1300:
            reward += 0.2

        self.current_step += 1
        if self.current_step >= self.max_steps - 1:
            done = True

        return self._get_obs(), reward, done, {}

    def render(self, mode='human'):
        row = self.data.iloc[self.current_step]
        print(f"Step {self.current_step} - Temp: {row['temp']}°C, Humid: {row['humid']}%")

# === 訓練模型 ===
csv_path = "/content/temperature_humidity_log.csv"
# csv_path = "/content/sample_data/temperature_humidity_2000.csv"  # 替換為你的 CSV 檔路徑
env = DummyVecEnv([lambda: THBLDC(csv_path)])
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=50000)

# === 儲存模型 ===
model.save("ppo_model")
print("✅ 模型已儲存為 ppo_model.zip")
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 592  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.030457307 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.4        |
# |    explained_variance   | 0.000297    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.88        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.065      |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.036304075 |
# |    clip_fraction        | 0.461       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.36       |
# |    explained_variance   | 0.00341     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.37        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0753     |
# |    value_loss           | 15.7        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 382       |
# |    iterations           | 4         |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0375586 |
# |    clip_fraction        | 0.448     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.32     |
# |    explained_variance   | 0.0026    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 11.4      |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -0.0694   |
# |    value_loss           | 21.4      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.042579785 |
# |    clip_fraction        | 0.498       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.27       |
# |    explained_variance   | 0.00178     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0741     |
# |    value_loss           | 25.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.041257206 |
# |    clip_fraction        | 0.515       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.22       |
# |    explained_variance   | 0.00137     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0754     |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 7           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.038730837 |
# |    clip_fraction        | 0.48        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.19       |
# |    explained_variance   | 0.00124     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0738     |
# |    value_loss           | 34.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 8           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.034604557 |
# |    clip_fraction        | 0.476       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.15       |
# |    explained_variance   | 0.00121     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0713     |
# |    value_loss           | 35.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 9           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.034476995 |
# |    clip_fraction        | 0.446       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.00157     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0665     |
# |    value_loss           | 37          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 10          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.034732334 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.1        |
# |    explained_variance   | 0.00212     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.073      |
# |    value_loss           | 40.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 371        |
# |    iterations           | 11         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03308827 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.08      |
# |    explained_variance   | 0.0039     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.1       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.071     |
# |    value_loss           | 38.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 12         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.03219965 |
# |    clip_fraction        | 0.453      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.04      |
# |    explained_variance   | 0.00586    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20.9       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0686    |
# |    value_loss           | 38.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 13          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.028574627 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7          |
# |    explained_variance   | 0.00904     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0672     |
# |    value_loss           | 39.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 14          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.030353269 |
# |    clip_fraction        | 0.43        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.95       |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0638     |
# |    value_loss           | 40.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 15          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.028191552 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.91       |
# |    explained_variance   | 0.019       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0677     |
# |    value_loss           | 38.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 16          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.027494371 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.89       |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0649     |
# |    value_loss           | 37.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 17          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.028695619 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.86       |
# |    explained_variance   | 0.0362      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0626     |
# |    value_loss           | 37.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 18          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.029543074 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.81       |
# |    explained_variance   | 0.0491      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0629     |
# |    value_loss           | 35          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 19          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024998743 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.77       |
# |    explained_variance   | 0.0651      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 35.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 20          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.024565674 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.7        |
# |    explained_variance   | 0.0839      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.056      |
# |    value_loss           | 34          |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 371       |
# |    iterations           | 21        |
# |    time_elapsed         | 115       |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0240953 |
# |    clip_fraction        | 0.29      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.66     |
# |    explained_variance   | 0.11      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 12.8      |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -0.0542   |
# |    value_loss           | 31.5      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 22          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.025344096 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.65       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 30.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 23          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.023793599 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.6        |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0493     |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 24          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.020756777 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.54       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.11        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0482     |
# |    value_loss           | 28.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 25          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023147339 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.47       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.93        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0493     |
# |    value_loss           | 26.7        |
# -----------------------------------------
# ✅ 模型已儲存為 ppo_model.zip

# %%
def test_model(model, env, episodes=500):
    total_rewards = []
    for ep in range(episodes):
        obs = env.reset()
        done = False
        ep_reward = 0
        while not done:
            action, _ = model.predict(obs)
            obs, reward, done, _ = env.step(action)
            ep_reward += abs(reward)
        total_rewards.append(ep_reward)
        print(f"Episode {ep+1}: Score = {abs(ep_reward)}")
    print(f"\n📊 Average Score: {np.mean(total_rewards)}")

# === 測試模型執行 ===
test_model(model, env)
# Out:
# Episode 1: Score = [38.79066]
# Episode 2: Score = [40.368664]
# Episode 3: Score = [43.55522]
# Episode 4: Score = [41.380486]
# Episode 5: Score = [41.456947]
# Episode 6: Score = [39.39894]
# Episode 7: Score = [41.37857]
# Episode 8: Score = [40.042313]
# Episode 9: Score = [36.746834]
# Episode 10: Score = [40.385784]
# Episode 11: Score = [39.08086]
# Episode 12: Score = [42.406887]
# Episode 13: Score = [42.829746]
# Episode 14: Score = [36.438553]
# Episode 15: Score = [41.181076]
# Episode 16: Score = [41.56693]
# Episode 17: Score = [41.987316]
# Episode 18: Score = [40.3747]
# Episode 19: Score = [38.032944]
# Episode 20: Score = [44.949486]
# Episode 21: Score = [39.888226]
# Episode 22: Score = [41.351353]
# Episode 23: Score = [39.60436]
# Episode 24: Score = [42.872025]
# Episode 25: Score = [41.38357]
# Episode 26: Score = [37.01795]
# Episode 27: Score = [40.106552]
# Episode 28: Score = [39.089695]
# Episode 29: Score = [41.850258]
# Episode 30: Score = [39.27116]
# Episode 31: Score = [42.340008]
# Episode 32: Score = [43.644016]
# Episode 33: Score = [42.655876]
# Episode 34: Score = [38.998608]
# Episode 35: Score = [36.71198]
# Episode 36: Score = [42.07702]
# Episode 37: Score = [39.354446]
# Episode 38: Score = [43.248306]
# Episode 39: Score = [42.43413]
# Episode 40: Score = [40.749626]
# Episode 41: Score = [40.982025]
# Episode 42: Score = [42.53729]
# Episode 43: Score = [39.985344]
# Episode 44: Score = [40.966637]
# Episode 45: Score = [35.67558]
# Episode 46: Score = [41.82948]
# Episode 47: Score = [39.355198]
# Episode 48: Score = [38.644768]
# Episode 49: Score = [38.9304]
# Episode 50: Score = [41.268986]
# Episode 51: Score = [42.03195]
# Episode 52: Score = [44.59352]
# Episode 53: Score = [41.53802]
# Episode 54: Score = [38.08072]
# Episode 55: Score = [39.014004]
# Episode 56: Score = [44.48833]
# Episode 57: Score = [46.004196]
# Episode 58: Score = [44.086994]
# Episode 59: Score = [39.036842]
# Episode 60: Score = [43.261284]
# Episode 61: Score = [43.71426]
# Episode 62: Score = [38.247066]
# Episode 63: Score = [42.166435]
# Episode 64: Score = [44.19585]
# Episode 65: Score = [39.643463]
# Episode 66: Score = [39.1133]
# Episode 67: Score = [39.236816]
# Episode 68: Score = [38.295437]
# Episode 69: Score = [42.12651]
# Episode 70: Score = [40.636326]
# Episode 71: Score = [42.40969]
# Episode 72: Score = [42.807426]
# Episode 73: Score = [44.41666]
# Episode 74: Score = [38.61707]
# Episode 75: Score = [41.300068]
# Episode 76: Score = [39.1788]
# Episode 77: Score = [40.816196]
# Episode 78: Score = [41.32731]
# Episode 79: Score = [41.166706]
# Episode 80: Score = [41.8912]
# Episode 81: Score = [37.091747]
# Episode 82: Score = [43.208187]
# Episode 83: Score = [38.25714]
# Episode 84: Score = [38.75598]
# Episode 85: Score = [41.917477]
# Episode 86: Score = [41.31501]
# Episode 87: Score = [40.75032]
# Episode 88: Score = [40.62706]
# Episode 89: Score = [44.02756]
# Episode 90: Score = [41.33742]
# Episode 91: Score = [41.664146]
# Episode 92: Score = [42.58528]
# Episode 93: Score = [41.365566]
# Episode 94: Score = [41.445488]
# Episode 95: Score = [38.69773]
# Episode 96: Score = [36.79429]
# Episode 97: Score = [38.765812]
# Episode 98: Score = [40.111855]
# Episode 99: Score = [42.512653]
# Episode 100: Score = [41.080597]
# Episode 101: Score = [39.741493]
# Episode 102: Score = [42.27987]
# Episode 103: Score = [43.922325]
# Episode 104: Score = [34.426273]
# Episode 105: Score = [37.58789]
# Episode 106: Score = [41.60103]
# Episode 107: Score = [42.637207]
# Episode 108: Score = [43.66554]
# Episode 109: Score = [38.946777]
# Episode 110: Score = [40.4042]
# Episode 111: Score = [38.4708]
# Episode 112: Score = [37.336143]
# Episode 113: Score = [40.24816]
# Episode 114: Score = [40.60519]
# Episode 115: Score = [39.393806]
# Episode 116: Score = [42.794838]
# Episode 117: Score = [43.63481]
# Episode 118: Score = [41.693966]
# Episode 119: Score = [43.744793]
# Episode 120: Score = [42.87289]
# Episode 121: Score = [40.586864]
# Episode 122: Score = [37.519974]
# Episode 123: Score = [37.873585]
# Episode 124: Score = [47.285892]
# Episode 125: Score = [43.394688]
# Episode 126: Score = [43.98493]
# Episode 127: Score = [38.746773]
# Episode 128: Score = [37.60257]
# Episode 129: Score = [39.85916]
# Episode 130: Score = [42.05505]
# Episode 131: Score = [40.216908]
# Episode 132: Score = [40.35399]
# Episode 133: Score = [38.300358]
# Episode 134: Score = [41.91236]
# Episode 135: Score = [42.888714]
# Episode 136: Score = [41.56608]
# Episode 137: Score = [42.32542]
# Episode 138: Score = [40.494965]
# Episode 139: Score = [44.413883]
# Episode 140: Score = [40.62615]
# Episode 141: Score = [40.699436]
# Episode 142: Score = [37.725346]
# Episode 143: Score = [38.008987]
# Episode 144: Score = [37.930527]
# Episode 145: Score = [39.336964]
# Episode 146: Score = [41.535294]
# Episode 147: Score = [43.948128]
# Episode 148: Score = [42.340908]
# Episode 149: Score = [39.251682]
# Episode 150: Score = [36.800064]
# Episode 151: Score = [37.642433]
# Episode 152: Score = [40.1048]
# Episode 153: Score = [39.02235]
# Episode 154: Score = [39.778725]
# Episode 155: Score = [43.371346]
# Episode 156: Score = [42.552982]
# Episode 157: Score = [38.61727]
# Episode 158: Score = [44.263474]
# Episode 159: Score = [41.375656]
# Episode 160: Score = [39.655178]
# Episode 161: Score = [44.333538]
# Episode 162: Score = [39.107574]
# Episode 163: Score = [40.59369]
# Episode 164: Score = [42.528088]
# Episode 165: Score = [40.79826]
# Episode 166: Score = [38.531883]
# Episode 167: Score = [43.847744]
# Episode 168: Score = [39.44216]
# Episode 169: Score = [40.331936]
# Episode 170: Score = [39.442783]
# Episode 171: Score = [42.737297]
# Episode 172: Score = [44.77857]
# Episode 173: Score = [39.35559]
# Episode 174: Score = [43.211033]
# Episode 175: Score = [43.497013]
# Episode 176: Score = [40.693092]
# Episode 177: Score = [47.382866]
# Episode 178: Score = [42.472626]
# Episode 179: Score = [41.94213]
# Episode 180: Score = [38.523956]
# Episode 181: Score = [42.306873]
# Episode 182: Score = [40.890778]
# Episode 183: Score = [41.15745]
# Episode 184: Score = [39.686195]
# Episode 185: Score = [40.671608]
# Episode 186: Score = [42.32404]
# Episode 187: Score = [37.352047]
# Episode 188: Score = [40.598083]
# Episode 189: Score = [43.47392]
# Episode 190: Score = [41.364403]
# Episode 191: Score = [42.437435]
# Episode 192: Score = [38.477882]
# Episode 193: Score = [43.423462]
# Episode 194: Score = [38.89257]
# Episode 195: Score = [43.350147]
# Episode 196: Score = [37.4011]
# Episode 197: Score = [42.98555]
# Episode 198: Score = [37.589024]
# Episode 199: Score = [40.30091]
# Episode 200: Score = [45.47378]
# Episode 201: Score = [41.463017]
# Episode 202: Score = [42.746914]
# Episode 203: Score = [37.965687]
# Episode 204: Score = [44.98092]
# Episode 205: Score = [43.726734]
# Episode 206: Score = [38.99493]
# Episode 207: Score = [41.145283]
# Episode 208: Score = [44.07664]
# Episode 209: Score = [41.52454]
# Episode 210: Score = [39.94537]
# Episode 211: Score = [41.895527]
# Episode 212: Score = [42.291405]
# Episode 213: Score = [39.368244]
# Episode 214: Score = [38.663174]
# Episode 215: Score = [42.46719]
# Episode 216: Score = [44.068024]
# Episode 217: Score = [43.637794]
# Episode 218: Score = [33.33808]
# Episode 219: Score = [39.969387]
# Episode 220: Score = [37.987354]
# Episode 221: Score = [36.973293]
# Episode 222: Score = [42.477295]
# Episode 223: Score = [39.932957]
# Episode 224: Score = [45.848816]
# Episode 225: Score = [40.84372]
# Episode 226: Score = [45.252007]
# Episode 227: Score = [42.041996]
# Episode 228: Score = [44.94626]
# Episode 229: Score = [38.799786]
# Episode 230: Score = [38.042027]
# Episode 231: Score = [42.064747]
# Episode 232: Score = [38.560276]
# Episode 233: Score = [42.84045]
# Episode 234: Score = [40.310005]
# Episode 235: Score = [34.883785]
# Episode 236: Score = [43.524757]
# Episode 237: Score = [36.247654]
# Episode 238: Score = [35.189365]
# Episode 239: Score = [40.474113]
# Episode 240: Score = [43.752945]
# Episode 241: Score = [37.41945]
# Episode 242: Score = [37.29027]
# Episode 243: Score = [37.7663]
# Episode 244: Score = [44.116234]
# Episode 245: Score = [38.51082]
# Episode 246: Score = [38.59721]
# Episode 247: Score = [42.009983]
# Episode 248: Score = [39.208347]
# Episode 249: Score = [35.72731]
# Episode 250: Score = [46.11481]
# Episode 251: Score = [39.923004]
# Episode 252: Score = [43.772762]
# Episode 253: Score = [37.927544]
# Episode 254: Score = [38.62294]
# Episode 255: Score = [43.535065]
# Episode 256: Score = [39.76645]
# Episode 257: Score = [40.91629]
# Episode 258: Score = [40.137005]
# Episode 259: Score = [42.806767]
# Episode 260: Score = [41.950874]
# Episode 261: Score = [42.057293]
# Episode 262: Score = [35.490643]
# Episode 263: Score = [39.420666]
# Episode 264: Score = [39.67445]
# Episode 265: Score = [39.263763]
# Episode 266: Score = [40.955082]
# Episode 267: Score = [43.4943]
# Episode 268: Score = [42.893238]
# Episode 269: Score = [43.846573]
# Episode 270: Score = [42.76594]
# Episode 271: Score = [41.013386]
# Episode 272: Score = [38.835396]
# Episode 273: Score = [38.500206]
# Episode 274: Score = [39.55567]
# Episode 275: Score = [38.737003]
# Episode 276: Score = [45.271393]
# Episode 277: Score = [37.903454]
# Episode 278: Score = [38.06554]
# Episode 279: Score = [41.02539]
# Episode 280: Score = [43.269314]
# Episode 281: Score = [39.233067]
# Episode 282: Score = [39.119247]
# Episode 283: Score = [36.910923]
# Episode 284: Score = [40.00307]
# Episode 285: Score = [41.872505]
# Episode 286: Score = [41.977562]
# Episode 287: Score = [41.744884]
# Episode 288: Score = [39.78666]
# Episode 289: Score = [40.006706]
# Episode 290: Score = [41.35745]
# Episode 291: Score = [40.87632]
# Episode 292: Score = [38.40953]
# Episode 293: Score = [43.15779]
# Episode 294: Score = [42.15942]
# Episode 295: Score = [38.428005]
# Episode 296: Score = [40.025913]
# Episode 297: Score = [43.17193]
# Episode 298: Score = [38.362484]
# Episode 299: Score = [38.39035]
# Episode 300: Score = [42.475174]
# Episode 301: Score = [41.60512]
# Episode 302: Score = [41.771828]
# Episode 303: Score = [42.916786]
# Episode 304: Score = [41.60091]
# Episode 305: Score = [42.14456]
# Episode 306: Score = [40.568977]
# Episode 307: Score = [39.45175]
# Episode 308: Score = [40.824284]
# Episode 309: Score = [36.602245]
# Episode 310: Score = [40.208004]
# Episode 311: Score = [39.786423]
# Episode 312: Score = [39.855614]
# Episode 313: Score = [40.759792]
# Episode 314: Score = [43.352985]
# Episode 315: Score = [43.81592]
# Episode 316: Score = [45.40326]
# Episode 317: Score = [40.97111]
# Episode 318: Score = [39.63835]
# Episode 319: Score = [46.58752]
# Episode 320: Score = [40.9719]
# Episode 321: Score = [39.208374]
# Episode 322: Score = [42.621212]
# Episode 323: Score = [36.011486]
# Episode 324: Score = [42.466125]
# Episode 325: Score = [37.941776]
# Episode 326: Score = [42.37148]
# Episode 327: Score = [43.961132]
# Episode 328: Score = [41.468697]
# Episode 329: Score = [36.975937]
# Episode 330: Score = [37.45184]
# Episode 331: Score = [40.863876]
# Episode 332: Score = [40.98853]
# Episode 333: Score = [37.68091]
# Episode 334: Score = [38.411568]
# Episode 335: Score = [41.093094]
# Episode 336: Score = [38.34931]
# Episode 337: Score = [41.621357]
# Episode 338: Score = [39.19336]
# Episode 339: Score = [40.20991]
# Episode 340: Score = [44.310104]
# Episode 341: Score = [37.363964]
# Episode 342: Score = [38.114532]
# Episode 343: Score = [37.52359]
# Episode 344: Score = [41.60766]
# Episode 345: Score = [40.266994]
# Episode 346: Score = [40.882442]
# Episode 347: Score = [42.666077]
# Episode 348: Score = [42.53492]
# Episode 349: Score = [42.012848]
# Episode 350: Score = [37.54799]
# Episode 351: Score = [40.50456]
# Episode 352: Score = [35.7147]
# Episode 353: Score = [40.773994]
# Episode 354: Score = [42.13349]
# Episode 355: Score = [42.991756]
# Episode 356: Score = [38.586395]
# Episode 357: Score = [37.668568]
# Episode 358: Score = [42.023666]
# Episode 359: Score = [37.90333]
# Episode 360: Score = [40.219925]
# Episode 361: Score = [42.76018]
# Episode 362: Score = [35.04828]
# Episode 363: Score = [40.885246]
# Episode 364: Score = [42.723858]
# Episode 365: Score = [44.758396]
# Episode 366: Score = [42.015484]
# Episode 367: Score = [42.18557]
# Episode 368: Score = [44.081703]
# Episode 369: Score = [43.3072]
# Episode 370: Score = [38.68719]
# Episode 371: Score = [45.700314]
# Episode 372: Score = [37.641644]
# Episode 373: Score = [40.418407]
# Episode 374: Score = [44.303352]
# Episode 375: Score = [46.765762]
# Episode 376: Score = [40.722824]
# Episode 377: Score = [39.39542]
# Episode 378: Score = [38.44555]
# Episode 379: Score = [37.312843]
# Episode 380: Score = [42.968346]
# Episode 381: Score = [38.021175]
# Episode 382: Score = [38.374695]
# Episode 383: Score = [36.504166]
# Episode 384: Score = [35.735924]
# Episode 385: Score = [41.562016]
# Episode 386: Score = [41.73933]
# Episode 387: Score = [33.884567]
# Episode 388: Score = [44.27031]
# Episode 389: Score = [40.853333]
# Episode 390: Score = [38.21978]
# Episode 391: Score = [35.45007]
# Episode 392: Score = [39.92723]
# Episode 393: Score = [43.934795]
# Episode 394: Score = [44.370323]
# Episode 395: Score = [42.69002]
# Episode 396: Score = [41.507645]
# Episode 397: Score = [39.89737]
# Episode 398: Score = [39.811882]
# Episode 399: Score = [40.057583]
# Episode 400: Score = [42.075413]
# Episode 401: Score = [41.84825]
# Episode 402: Score = [41.53281]
# Episode 403: Score = [39.048626]
# Episode 404: Score = [39.932327]
# Episode 405: Score = [38.762012]
# Episode 406: Score = [38.54793]
# Episode 407: Score = [44.74824]
# Episode 408: Score = [39.927364]
# Episode 409: Score = [37.292477]
# Episode 410: Score = [41.363895]
# Episode 411: Score = [37.684517]
# Episode 412: Score = [42.789806]
# Episode 413: Score = [41.327065]
# Episode 414: Score = [41.504303]
# Episode 415: Score = [40.311275]
# Episode 416: Score = [39.822105]
# Episode 417: Score = [40.263855]
# Episode 418: Score = [38.52635]
# Episode 419: Score = [44.258274]
# Episode 420: Score = [39.450558]
# Episode 421: Score = [39.05914]
# Episode 422: Score = [40.83738]
# Episode 423: Score = [39.337994]
# Episode 424: Score = [40.63327]
# Episode 425: Score = [37.748077]
# Episode 426: Score = [39.94338]
# Episode 427: Score = [40.252903]
# Episode 428: Score = [42.59226]
# Episode 429: Score = [41.79617]
# Episode 430: Score = [41.348545]
# Episode 431: Score = [40.082363]
# Episode 432: Score = [45.10203]
# Episode 433: Score = [39.800518]
# Episode 434: Score = [37.90087]
# Episode 435: Score = [40.71516]
# Episode 436: Score = [40.663048]
# Episode 437: Score = [41.671337]
# Episode 438: Score = [41.466434]
# Episode 439: Score = [40.493587]
# Episode 440: Score = [44.598907]
# Episode 441: Score = [43.52931]
# Episode 442: Score = [40.30532]
# Episode 443: Score = [45.125095]
# Episode 444: Score = [42.29674]
# Episode 445: Score = [42.18907]
# Episode 446: Score = [39.293564]
# Episode 447: Score = [41.686207]
# Episode 448: Score = [40.298702]
# Episode 449: Score = [41.37813]
# Episode 450: Score = [37.82989]
# Episode 451: Score = [38.697975]
# Episode 452: Score = [38.96665]
# Episode 453: Score = [40.862667]
# Episode 454: Score = [36.16693]
# Episode 455: Score = [45.79462]
# Episode 456: Score = [39.496586]
# Episode 457: Score = [41.01416]
# Episode 458: Score = [37.159668]
# Episode 459: Score = [46.47729]
# Episode 460: Score = [42.924805]
# Episode 461: Score = [39.488644]
# Episode 462: Score = [40.559933]
# Episode 463: Score = [37.18129]
# Episode 464: Score = [35.82963]
# Episode 465: Score = [38.44352]
# Episode 466: Score = [39.69148]
# Episode 467: Score = [39.217773]
# Episode 468: Score = [41.36896]
# Episode 469: Score = [41.037025]
# Episode 470: Score = [39.489735]
# Episode 471: Score = [43.572773]
# Episode 472: Score = [40.885666]
# Episode 473: Score = [42.613316]
# Episode 474: Score = [40.337666]
# Episode 475: Score = [41.747868]
# Episode 476: Score = [44.415607]
# Episode 477: Score = [42.825798]
# Episode 478: Score = [41.5304]
# Episode 479: Score = [39.818275]
# Episode 480: Score = [43.488865]
# Episode 481: Score = [42.643745]
# Episode 482: Score = [39.189274]
# Episode 483: Score = [38.792057]
# Episode 484: Score = [40.353027]
# Episode 485: Score = [40.71467]
# Episode 486: Score = [39.174118]
# Episode 487: Score = [38.789753]
# Episode 488: Score = [37.945663]
# Episode 489: Score = [42.33399]
# Episode 490: Score = [44.575466]
# Episode 491: Score = [35.77387]
# Episode 492: Score = [42.21699]
# Episode 493: Score = [43.1102]
# Episode 494: Score = [34.455296]
# Episode 495: Score = [38.88097]
# Episode 496: Score = [43.095688]
# Episode 497: Score = [40.227978]
# Episode 498: Score = [43.42562]
# Episode 499: Score = [35.81691]
# Episode 500: Score = [42.613274]
#
# 📊 Average Score: 40.723506927490234

# %%
# 讀取模型
model = PPO.load("ppo_model.zip")

# 單筆資料（範例）
#  Temperature, Humidity
current_status = [26, 40]


obs = np.array([
    current_status[0] / 100,
    current_status[1] / 100
], dtype=np.float32)



  # 模型預測
action, _ = model.predict(obs, deterministic=True)


print(obs, action)
# Out:
# [0.26 0.4 ] 782

# %%
import gym
import numpy as np
import pandas as pd
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 環境（使用 CSV）
class THBLDC(gym.Env):
    def __init__(self, csv_path):
        self.data = pd.read_csv(csv_path)
        self.max_steps = len(self.data)

        # 狀態空間：2 維連續數值（標準化）
        self.observation_space = spaces.Box(low=0, high=1, shape=(2,), dtype=np.float32)

        # 動作空間：0 to 1650 rpm
        self.action_space = spaces.Discrete(1651)
        self.current_step = 0

    def reset(self):
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        row = self.data.iloc[self.current_step]
        return np.array([
            row['Temperature'] / 100,
            row['Humidity'] / 100
        ], dtype=np.float32)

    def step(self, action):
        row = self.data.iloc[self.current_step]
        done = False
        reward = 0

        temp = row['Temperature']
        humid = row['Humidity']

        # RPM 計算電力消耗
        rpm = action
        power_watt = (rpm / 1650) ** 3 * 100  # 假設最大功率為 100W
        kwh = (power_watt * 0.1) / 1000       # 0.1 小時為每步長
        tr_fan = 0.006                        # 傳統風扇能耗為 0.006 kWh
        save_rate = (tr_fan - kwh) / tr_fan

        # 節能效果（希望 kWh 越少越好）
        reward += -kwh  # 直接懲罰功耗

        # 溫度舒適度（22–28°C 為舒適範圍）
        reward += -abs(temp - 25) * 0.1  # 越接近 25°C 越好

        # 濕度舒適度（40–60% 為舒適範圍）
        reward += -abs(humid - 50) * 0.05  # 越接近 50% 越好

        # 若功耗比基準省電 30% 以上，額外加分
        if save_rate >= 0.3:
            reward += 0.5

        # 若風速在舒適風速區間（ex. 500~900 RPM），額外加分
        if 500 <= action <= 900:
            reward += 0.2


        self.current_step += 1
        if self.current_step >= self.max_steps - 1:
            done = True

        return self._get_obs(), reward, done, {}

    def render(self, mode='human'):
        row = self.data.iloc[self.current_step]
        print(f"Step {self.current_step} - Temp: {row['Temperature (°C)']} °C, Humid: {row['Humidity (%)']} %")

# === 訓練模型 ===
csv_path = "/content/temperature_humidity_log.csv"  # 替換為你的 CSV 檔路徑
env = DummyVecEnv([lambda: THBLDC(csv_path)])
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=500000)

# === 儲存模型 ===
model.save("ppo_ups_battery_model")
print("✅ 模型已儲存為 ppo_ups_battery_model.zip")

# === 測試模型 ===
def test_model(model, env, episodes=1000):
    total_rewards = []
    for ep in range(episodes):
        obs = env.reset()
        done = False
        ep_reward = 0
        while not done:
            action, _ = model.predict(obs)
            obs, reward, done, _ = env.step(action)
            ep_reward += reward
        total_rewards.append(ep_reward)
        print(f"Episode {ep+1}: Score = {ep_reward}")
    print(f"\n📊 Average Score: {np.mean(total_rewards)}")

# === 測試模型執行 ===
test_model(model, env)
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# 串流輸出內容已截斷至最後 5000 行。
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 24          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025131298 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.8        |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0564     |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 25          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.025791861 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.78       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0574     |
# |    value_loss           | 42.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 360        |
# |    iterations           | 26         |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.02695837 |
# |    clip_fraction        | 0.304      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.73      |
# |    explained_variance   | 0.193      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.2       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.053     |
# |    value_loss           | 40         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 27          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.027912684 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.72       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 36.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 28          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.024426918 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.68       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0477     |
# |    value_loss           | 34.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 360        |
# |    iterations           | 29         |
# |    time_elapsed         | 164        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02223593 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.62      |
# |    explained_variance   | 0.344      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.9       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0481    |
# |    value_loss           | 30.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 30          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.027198872 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.56       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 28.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 31          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022356562 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.5        |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 27.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 32         |
# |    time_elapsed         | 182        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02297776 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.45      |
# |    explained_variance   | 0.479      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.3       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0459    |
# |    value_loss           | 24.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 358        |
# |    iterations           | 33         |
# |    time_elapsed         | 188        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02627755 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.38      |
# |    explained_variance   | 0.527      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.54       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0429    |
# |    value_loss           | 22.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 34          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022208475 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.35       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 20.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 35          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.031604905 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.32       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 16.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 36          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.024824336 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.25       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 37          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.028125342 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.19       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.79        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 14.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 38          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.032233432 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.14       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.35        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 12.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 39          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.023012571 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.07       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.44        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 9.5         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 40         |
# |    time_elapsed         | 228        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03275158 |
# |    clip_fraction        | 0.352      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.97      |
# |    explained_variance   | 0.836      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.67       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0397    |
# |    value_loss           | 8.79       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 41          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028470512 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.92       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.76        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 8.15        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 42          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.021554688 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 6.74        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 43          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.027749408 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.1         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 5.75        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 44         |
# |    time_elapsed         | 250        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03173162 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.76      |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.12       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0354    |
# |    value_loss           | 5.81       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 45          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.029214945 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 5.03        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 46          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.021483388 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 4.55        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 359       |
# |    iterations           | 47        |
# |    time_elapsed         | 267       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0243753 |
# |    clip_fraction        | 0.266     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.52     |
# |    explained_variance   | 0.914     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.03      |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.0358   |
# |    value_loss           | 4.27      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 48         |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02554633 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.49      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.71       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.03      |
# |    value_loss           | 3.68       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 49          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.029146086 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 3.58        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 50          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.031659633 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.955       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 51          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.027130203 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.24       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 3.97        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 52          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.027841862 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 3.94        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 53          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.020463556 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 4.09        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 54          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.027568929 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 3.9         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 55          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.022904582 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.91       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0276     |
# |    value_loss           | 3.36        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 56          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.028412435 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.88       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.943       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 57          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.024846483 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.76       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 58          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.021471798 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.883       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 358        |
# |    iterations           | 59         |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.02440199 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.57      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.28       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0178    |
# |    value_loss           | 2.69       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 60          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.017000142 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 2.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 61          |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.022806086 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 62          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.021981873 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 63          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.022824014 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.991       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.023      |
# |    value_loss           | 2.11        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 358        |
# |    iterations           | 64         |
# |    time_elapsed         | 365        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.02120241 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.66      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.962      |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0215    |
# |    value_loss           | 1.97       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 65          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.025049321 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 2.09        |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 358      |
# |    iterations           | 66       |
# |    time_elapsed         | 377      |
# |    total_timesteps      | 135168   |
# | train/                  |          |
# |    approx_kl            | 0.018932 |
# |    clip_fraction        | 0.179    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.41    |
# |    explained_variance   | 0.938    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.639    |
# |    n_updates            | 650      |
# |    policy_gradient_loss | -0.0184  |
# |    value_loss           | 2.2      |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 67          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 137216      |
# | train/                  |             |
# |    approx_kl            | 0.017017579 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 68          |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.031485997 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.959       |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 1.99        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 69          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.011263169 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 70          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.021671249 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.871       |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 71          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 145408      |
# | train/                  |             |
# |    approx_kl            | 0.011408671 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33        |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 2.11        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 72           |
# |    time_elapsed         | 410          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0152136665 |
# |    clip_fraction        | 0.186        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39         |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.0196      |
# |    value_loss           | 1.79         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 73          |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 149504      |
# | train/                  |             |
# |    approx_kl            | 0.006911513 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 1.83        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 74          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.007219186 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.644       |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 1.6         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 75          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 153600      |
# | train/                  |             |
# |    approx_kl            | 0.008738056 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.93        |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 1.66        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 76          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.009139708 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 1.76        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 77          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 157696      |
# | train/                  |             |
# |    approx_kl            | 0.013119819 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.823       |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.00755    |
# |    value_loss           | 1.52        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 78          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.008652504 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.538       |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 79          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 161792      |
# | train/                  |             |
# |    approx_kl            | 0.014256124 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.846       |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 1.44        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 80          |
# |    time_elapsed         | 457         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.009279029 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 1.57        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 81           |
# |    time_elapsed         | 462          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0078502055 |
# |    clip_fraction        | 0.0809       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.581        |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 1.66         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 82          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.011486458 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 1.67        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 83          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.012474572 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.691       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 84          |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.010253321 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.502       |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 1.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 85          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.011613086 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.67        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00744    |
# |    value_loss           | 1.41        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 357        |
# |    iterations           | 86         |
# |    time_elapsed         | 492        |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.01171569 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.548      |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.00686   |
# |    value_loss           | 1.66       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 87          |
# ...
# Episode 532: Score = [-27.632149]
# Episode 533: Score = [-27.632883]
# Episode 534: Score = [-27.632149]
# Episode 535: Score = [-27.632149]
# Episode 536: Score = [-27.632149]
# Episode 537: Score = [-27.632149]
# Episode 538: Score = [-27.631937]
# Episode 539: Score = [-27.632149]
# Episode 540: Score = [-27.632149]
# Episode 541: Score = [-27.632149]
# Episode 542: Score = [-27.632149]
# Episode 543: Score = [-27.632149]
# Episode 544: Score = [-27.632149]
# Episode 545: Score = [-27.632149]
# Episode 546: Score = [-27.632149]
# Episode 547: Score = [-27.632149]
# Episode 548: Score = [-27.632149]
# Episode 549: Score = [-27.632149]
# Episode 550: Score = [-27.632149]
# Episode 551: Score = [-27.632149]
# Episode 552: Score = [-27.631937]
# Episode 553: Score = [-27.632149]
# Episode 554: Score = [-27.632149]
# Episode 555: Score = [-27.632149]
# Episode 556: Score = [-27.632149]
# Episode 557: Score = [-27.632149]
# Episode 558: Score = [-27.632149]
# Episode 559: Score = [-27.632149]
# Episode 560: Score = [-27.632149]
# Episode 561: Score = [-27.632149]
# Episode 562: Score = [-27.632149]
# Episode 563: Score = [-27.632149]
# Episode 564: Score = [-27.632149]
# Episode 565: Score = [-27.632149]
# Episode 566: Score = [-27.632149]
# Episode 567: Score = [-27.631937]
# Episode 568: Score = [-27.632149]
# Episode 569: Score = [-27.632149]
# Episode 570: Score = [-27.632149]
# Episode 571: Score = [-27.6325]
# Episode 572: Score = [-27.632149]
# Episode 573: Score = [-27.632149]
# Episode 574: Score = [-27.632149]
# Episode 575: Score = [-27.632149]
# Episode 576: Score = [-27.631937]
# Episode 577: Score = [-27.631937]
# Episode 578: Score = [-27.632885]
# Episode 579: Score = [-27.631937]
# Episode 580: Score = [-27.632149]
# Episode 581: Score = [-27.632149]
# Episode 582: Score = [-27.632149]
# Episode 583: Score = [-27.632149]
# Episode 584: Score = [-27.632149]
# Episode 585: Score = [-27.632149]
# Episode 586: Score = [-27.632149]
# Episode 587: Score = [-27.63171]
# Episode 588: Score = [-27.632149]
# Episode 589: Score = [-27.632149]
# Episode 590: Score = [-27.632149]
# Episode 591: Score = [-27.632149]
# Episode 592: Score = [-27.632149]
# Episode 593: Score = [-27.631937]
# Episode 594: Score = [-27.632149]
# Episode 595: Score = [-27.632149]
# Episode 596: Score = [-27.632883]
# Episode 597: Score = [-27.632149]
# Episode 598: Score = [-27.632248]
# Episode 599: Score = [-27.631939]
# Episode 600: Score = [-27.632149]
# Episode 601: Score = [-27.632149]
# Episode 602: Score = [-27.632149]
# Episode 603: Score = [-27.632883]
# Episode 604: Score = [-27.632149]
# Episode 605: Score = [-27.632149]
# Episode 606: Score = [-27.632149]
# Episode 607: Score = [-27.632149]
# Episode 608: Score = [-27.632149]
# Episode 609: Score = [-27.632149]
# Episode 610: Score = [-27.632149]
# Episode 611: Score = [-27.631937]
# Episode 612: Score = [-27.632149]
# Episode 613: Score = [-27.631952]
# Episode 614: Score = [-27.632149]
# Episode 615: Score = [-27.632149]
# Episode 616: Score = [-27.631939]
# Episode 617: Score = [-27.632149]
# Episode 618: Score = [-27.632149]
# Episode 619: Score = [-27.631868]
# Episode 620: Score = [-27.632149]
# Episode 621: Score = [-27.632149]
# Episode 622: Score = [-27.632885]
# Episode 623: Score = [-27.632149]
# Episode 624: Score = [-27.632149]
# Episode 625: Score = [-27.632149]
# Episode 626: Score = [-27.632149]
# Episode 627: Score = [-27.632149]
# Episode 628: Score = [-27.632149]
# Episode 629: Score = [-27.631939]
# Episode 630: Score = [-27.632149]
# Episode 631: Score = [-27.632149]
# Episode 632: Score = [-27.632149]
# Episode 633: Score = [-27.632149]
# Episode 634: Score = [-27.632149]
# Episode 635: Score = [-27.632149]
# Episode 636: Score = [-27.632149]
# Episode 637: Score = [-27.632149]
# Episode 638: Score = [-27.632149]
# Episode 639: Score = [-27.632883]
# Episode 640: Score = [-27.632866]
# Episode 641: Score = [-27.632149]
# Episode 642: Score = [-27.632149]
# Episode 643: Score = [-27.632673]
# Episode 644: Score = [-27.632149]
# Episode 645: Score = [-27.632149]
# Episode 646: Score = [-27.632149]
# Episode 647: Score = [-27.632149]
# Episode 648: Score = [-27.631939]
# Episode 649: Score = [-27.632149]
# Episode 650: Score = [-27.632149]
# Episode 651: Score = [-27.631937]
# Episode 652: Score = [-27.632149]
# Episode 653: Score = [-27.632149]
# Episode 654: Score = [-27.632149]
# Episode 655: Score = [-27.632149]
# Episode 656: Score = [-27.632149]
# Episode 657: Score = [-27.632149]
# Episode 658: Score = [-27.631937]
# Episode 659: Score = [-27.632149]
# Episode 660: Score = [-27.632149]
# Episode 661: Score = [-27.632149]
# Episode 662: Score = [-27.631937]
# Episode 663: Score = [-27.631939]
# Episode 664: Score = [-27.632149]
# Episode 665: Score = [-27.632149]
# Episode 666: Score = [-27.632883]
# Episode 667: Score = [-27.632149]
# Episode 668: Score = [-27.632149]
# Episode 669: Score = [-27.631937]
# Episode 670: Score = [-27.632149]
# Episode 671: Score = [-27.632149]
# Episode 672: Score = [-27.632149]
# Episode 673: Score = [-27.632149]
# Episode 674: Score = [-27.632149]
# Episode 675: Score = [-27.632149]
# Episode 676: Score = [-27.632149]
# Episode 677: Score = [-27.632149]
# Episode 678: Score = [-27.632149]
# Episode 679: Score = [-27.632149]
# Episode 680: Score = [-27.632149]
# Episode 681: Score = [-27.632078]
# Episode 682: Score = [-27.632149]
# Episode 683: Score = [-27.632149]
# Episode 684: Score = [-27.632149]
# Episode 685: Score = [-27.632149]
# Episode 686: Score = [-27.631937]
# Episode 687: Score = [-27.632149]
# Episode 688: Score = [-27.632883]
# Episode 689: Score = [-27.632149]
# Episode 690: Score = [-27.632149]
# Episode 691: Score = [-27.632149]
# Episode 692: Score = [-27.631939]
# Episode 693: Score = [-27.632149]
# Episode 694: Score = [-27.63174]
# Episode 695: Score = [-27.632149]
# Episode 696: Score = [-27.632883]
# Episode 697: Score = [-27.631868]
# Episode 698: Score = [-27.632149]
# Episode 699: Score = [-27.632149]
# Episode 700: Score = [-27.632149]
# Episode 701: Score = [-27.632149]
# Episode 702: Score = [-27.632149]
# Episode 703: Score = [-27.631939]
# Episode 704: Score = [-27.632149]
# Episode 705: Score = [-27.631937]
# Episode 706: Score = [-27.632149]
# Episode 707: Score = [-27.632149]
# Episode 708: Score = [-27.632149]
# Episode 709: Score = [-27.632149]
# Episode 710: Score = [-27.632149]
# Episode 711: Score = [-27.631937]
# Episode 712: Score = [-27.632149]
# Episode 713: Score = [-27.632149]
# Episode 714: Score = [-27.632149]
# Episode 715: Score = [-27.632149]
# Episode 716: Score = [-27.632149]
# Episode 717: Score = [-27.632149]
# Episode 718: Score = [-27.632149]
# Episode 719: Score = [-27.632149]
# Episode 720: Score = [-27.632149]
# Episode 721: Score = [-27.632288]
# Episode 722: Score = [-27.631937]
# Episode 723: Score = [-27.631794]
# Episode 724: Score = [-27.632149]
# Episode 725: Score = [-27.632149]
# Episode 726: Score = [-27.632149]
# Episode 727: Score = [-27.632149]
# Episode 728: Score = [-27.632149]
# Episode 729: Score = [-27.631937]
# Episode 730: Score = [-27.632149]
# Episode 731: Score = [-27.632671]
# Episode 732: Score = [-27.632149]
# Episode 733: Score = [-27.632149]
# Episode 734: Score = [-27.632149]
# Episode 735: Score = [-27.631937]
# Episode 736: Score = [-27.632149]
# Episode 737: Score = [-27.632149]
# Episode 738: Score = [-27.632149]
# Episode 739: Score = [-27.632149]
# Episode 740: Score = [-27.632149]
# Episode 741: Score = [-27.632149]
# Episode 742: Score = [-27.632149]
# Episode 743: Score = [-27.632149]
# Episode 744: Score = [-27.632149]
# Episode 745: Score = [-27.632149]
# Episode 746: Score = [-27.63173]
# Episode 747: Score = [-27.632149]
# Episode 748: Score = [-27.632149]
# Episode 749: Score = [-27.632673]
# Episode 750: Score = [-27.632149]
# Episode 751: Score = [-27.632149]
# Episode 752: Score = [-27.632149]
# Episode 753: Score = [-27.632149]
# Episode 754: Score = [-27.632149]
# Episode 755: Score = [-27.632149]
# Episode 756: Score = [-27.632149]
# Episode 757: Score = [-27.632149]
# Episode 758: Score = [-27.632149]
# Episode 759: Score = [-27.632149]
# Episode 760: Score = [-27.632149]
# Episode 761: Score = [-27.632149]
# Episode 762: Score = [-27.632149]
# Episode 763: Score = [-27.632149]
# Episode 764: Score = [-27.63213]
# Episode 765: Score = [-27.632149]
# Episode 766: Score = [-27.631937]
# Episode 767: Score = [-27.632149]
# Episode 768: Score = [-27.632149]
# Episode 769: Score = [-27.632149]
# Episode 770: Score = [-27.632149]
# Episode 771: Score = [-27.632149]
# Episode 772: Score = [-27.632149]
# Episode 773: Score = [-27.632883]
# Episode 774: Score = [-27.631939]
# Episode 775: Score = [-27.632149]
# Episode 776: Score = [-27.632149]
# Episode 777: Score = [-27.632149]
# Episode 778: Score = [-27.632132]
# Episode 779: Score = [-27.631937]
# Episode 780: Score = [-27.632149]
# Episode 781: Score = [-27.632149]
# Episode 782: Score = [-27.632149]
# Episode 783: Score = [-27.632149]
# Episode 784: Score = [-27.632149]
# Episode 785: Score = [-27.632883]
# Episode 786: Score = [-27.631939]
# Episode 787: Score = [-27.632149]
# Episode 788: Score = [-27.632149]
# Episode 789: Score = [-27.632149]
# Episode 790: Score = [-27.632149]
# Episode 791: Score = [-27.631937]
# Episode 792: Score = [-27.631937]
# Episode 793: Score = [-27.632149]
# Episode 794: Score = [-27.631939]
# Episode 795: Score = [-27.632149]
# Episode 796: Score = [-27.632149]
# Episode 797: Score = [-27.632149]
# Episode 798: Score = [-27.631939]
# Episode 799: Score = [-27.632149]
# Episode 800: Score = [-27.632149]
# Episode 801: Score = [-27.632149]
# Episode 802: Score = [-27.632149]
# Episode 803: Score = [-27.632149]
# Episode 804: Score = [-27.632149]
# Episode 805: Score = [-27.632149]
# Episode 806: Score = [-27.632149]
# Episode 807: Score = [-27.632885]
# Episode 808: Score = [-27.632149]
# Episode 809: Score = [-27.632149]
# Episode 810: Score = [-27.632149]
# Episode 811: Score = [-27.632149]
# Episode 812: Score = [-27.632288]
# Episode 813: Score = [-27.632149]
# Episode 814: Score = [-27.632149]
# Episode 815: Score = [-27.632149]
# Episode 816: Score = [-27.632149]
# Episode 817: Score = [-27.632149]
# Episode 818: Score = [-27.632149]
# Episode 819: Score = [-27.632149]
# Episode 820: Score = [-27.632671]
# Episode 821: Score = [-27.632149]
# Episode 822: Score = [-27.632149]
# Episode 823: Score = [-27.632149]
# Episode 824: Score = [-27.632149]
# Episode 825: Score = [-27.631937]
# Episode 826: Score = [-27.631937]
# Episode 827: Score = [-27.632149]
# Episode 828: Score = [-27.632149]
# Episode 829: Score = [-27.632149]
# Episode 830: Score = [-27.632149]
# Episode 831: Score = [-27.632149]
# Episode 832: Score = [-27.632006]
# Episode 833: Score = [-27.632149]
# Episode 834: Score = [-27.632149]
# Episode 835: Score = [-27.632149]
# Episode 836: Score = [-27.632149]
# Episode 837: Score = [-27.632149]
# Episode 838: Score = [-27.632149]
# Episode 839: Score = [-27.632149]
# Episode 840: Score = [-27.632149]
# Episode 841: Score = [-27.632149]
# Episode 842: Score = [-27.632149]
# Episode 843: Score = [-27.632885]
# Episode 844: Score = [-27.632149]
# Episode 845: Score = [-27.632149]
# Episode 846: Score = [-27.631937]
# Episode 847: Score = [-27.63173]
# Episode 848: Score = [-27.631939]
# Episode 849: Score = [-27.632854]
# Episode 850: Score = [-27.631725]
# Episode 851: Score = [-27.632149]
# Episode 852: Score = [-27.632149]
# Episode 853: Score = [-27.632149]
# Episode 854: Score = [-27.632149]
# Episode 855: Score = [-27.632149]
# Episode 856: Score = [-27.632149]
# Episode 857: Score = [-27.632149]
# Episode 858: Score = [-27.632149]
# Episode 859: Score = [-27.632149]
# Episode 860: Score = [-27.632149]
# Episode 861: Score = [-27.63305]
# Episode 862: Score = [-27.631924]
# Episode 863: Score = [-27.632149]
# Episode 864: Score = [-27.632149]
# Episode 865: Score = [-27.633785]
# Episode 866: Score = [-27.632149]
# Episode 867: Score = [-28.338303]
# Episode 868: Score = [-27.632149]
# Episode 869: Score = [-27.631937]
# Episode 870: Score = [-27.632149]
# Episode 871: Score = [-27.632149]
# Episode 872: Score = [-27.632149]
# Episode 873: Score = [-27.632149]
# Episode 874: Score = [-27.632149]
# Episode 875: Score = [-27.632149]
# Episode 876: Score = [-27.632883]
# Episode 877: Score = [-27.632149]
# Episode 878: Score = [-27.632421]
# Episode 879: Score = [-27.632149]
# Episode 880: Score = [-27.632149]
# Episode 881: Score = [-27.631937]
# Episode 882: Score = [-27.632149]
# Episode 883: Score = [-27.632149]
# Episode 884: Score = [-27.632149]
# Episode 885: Score = [-27.632149]
# Episode 886: Score = [-27.632149]
# Episode 887: Score = [-27.632149]
# Episode 888: Score = [-27.632883]
# Episode 889: Score = [-27.632149]
# Episode 890: Score = [-27.632149]
# Episode 891: Score = [-27.632149]
# Episode 892: Score = [-27.632149]
# Episode 893: Score = [-27.632149]
# Episode 894: Score = [-27.632149]
# Episode 895: Score = [-27.631937]
# Episode 896: Score = [-27.632673]
# Episode 897: Score = [-27.632149]
# Episode 898: Score = [-27.631727]
# Episode 899: Score = [-27.631939]
# Episode 900: Score = [-27.632149]
# Episode 901: Score = [-27.632149]
# Episode 902: Score = [-27.632149]
# Episode 903: Score = [-27.632166]
# Episode 904: Score = [-27.632149]
# Episode 905: Score = [-27.632149]
# Episode 906: Score = [-27.632149]
# Episode 907: Score = [-27.632149]
# Episode 908: Score = [-27.835205]
# Episode 909: Score = [-27.632149]
# Episode 910: Score = [-27.632149]
# Episode 911: Score = [-27.632149]
# Episode 912: Score = [-27.632149]
# Episode 913: Score = [-27.632149]
# Episode 914: Score = [-27.632149]
# Episode 915: Score = [-27.632883]
# Episode 916: Score = [-27.632149]
# Episode 917: Score = [-27.632149]
# Episode 918: Score = [-27.632149]
# Episode 919: Score = [-27.632149]
# Episode 920: Score = [-27.632149]
# Episode 921: Score = [-27.631725]
# Episode 922: Score = [-27.632149]
# Episode 923: Score = [-27.631937]
# Episode 924: Score = [-27.632883]
# Episode 925: Score = [-27.632149]
# Episode 926: Score = [-27.632149]
# Episode 927: Score = [-27.632149]
# Episode 928: Score = [-27.632149]
# Episode 929: Score = [-27.632149]
# Episode 930: Score = [-27.632149]
# Episode 931: Score = [-27.632149]
# Episode 932: Score = [-27.632149]
# Episode 933: Score = [-27.632149]
# Episode 934: Score = [-27.631937]
# Episode 935: Score = [-27.632149]
# Episode 936: Score = [-27.632149]
# Episode 937: Score = [-27.631937]
# Episode 938: Score = [-27.632149]
# Episode 939: Score = [-27.632149]
# Episode 940: Score = [-27.632149]
# Episode 941: Score = [-27.631937]
# Episode 942: Score = [-27.631937]
# Episode 943: Score = [-27.632149]
# Episode 944: Score = [-27.632149]
# Episode 945: Score = [-27.632149]
# Episode 946: Score = [-27.632149]
# Episode 947: Score = [-27.632149]
# Episode 948: Score = [-27.632149]
# Episode 949: Score = [-27.632149]
# Episode 950: Score = [-27.631937]
# Episode 951: Score = [-27.632149]
# Episode 952: Score = [-27.632149]
# Episode 953: Score = [-27.632149]
# Episode 954: Score = [-27.632149]
# Episode 955: Score = [-27.631937]
# Episode 956: Score = [-27.632149]
# Episode 957: Score = [-27.632149]
# Episode 958: Score = [-27.632149]
# Episode 959: Score = [-27.632149]
# Episode 960: Score = [-27.632149]
# Episode 961: Score = [-27.631937]
# Episode 962: Score = [-27.632149]
# Episode 963: Score = [-27.632149]
# Episode 964: Score = [-27.632883]
# Episode 965: Score = [-27.632149]
# Episode 966: Score = [-27.632149]
# Episode 967: Score = [-27.632149]
# Episode 968: Score = [-27.632149]
# Episode 969: Score = [-27.631939]
# Episode 970: Score = [-27.631937]
# Episode 971: Score = [-27.632149]
# Episode 972: Score = [-27.632149]
# Episode 973: Score = [-27.632149]
# Episode 974: Score = [-27.632149]
# Episode 975: Score = [-27.632149]
# Episode 976: Score = [-27.632671]
# Episode 977: Score = [-27.632149]
# Episode 978: Score = [-27.632149]
# Episode 979: Score = [-27.632149]
# Episode 980: Score = [-27.632149]
# Episode 981: Score = [-27.632149]
# Episode 982: Score = [-27.632149]
# Episode 983: Score = [-27.631939]
# Episode 984: Score = [-27.632149]
# Episode 985: Score = [-27.632883]
# Episode 986: Score = [-27.632149]
# Episode 987: Score = [-27.631517]
# Episode 988: Score = [-27.632149]
# Episode 989: Score = [-27.632883]
# Episode 990: Score = [-27.632149]
# Episode 991: Score = [-27.631937]
# Episode 992: Score = [-27.632149]
# Episode 993: Score = [-27.632149]
# Episode 994: Score = [-27.632149]
# Episode 995: Score = [-27.632149]
# Episode 996: Score = [-27.631939]
# Episode 997: Score = [-27.632149]
# Episode 998: Score = [-27.632149]
# Episode 999: Score = [-27.632149]
# Episode 1000: Score = [-27.632149]
#
# 📊 Average Score: -27.634065628051758
